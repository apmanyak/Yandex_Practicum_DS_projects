# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импортируем-библиотеки" data-toc-modified-id="Импортируем-библиотеки-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импортируем библиотеки</a></span></li><li><span><a href="#Эффективность-обогащения" data-toc-modified-id="Эффективность-обогащения-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Эффективность обогащения</a></span></li><li><span><a href="#Анализ-признаков-в-выборке" data-toc-modified-id="Анализ-признаков-в-выборке-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Анализ признаков в выборке</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изменение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки" data-toc-modified-id="Изменение-концентрации-металлов-(Au,-Ag,-Pb)-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки</a></span></li><li><span><a href="#Сравнение--распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках." data-toc-modified-id="Сравнение--распределения-размеров-гранул-сырья-на-обучающей-и-тестовой-выборках.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравнение  распределения размеров гранул сырья на обучающей и тестовой выборках.</a></span></li><li><span><a href="#Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах." data-toc-modified-id="Исследование-суммарной-концентрации-всех-веществ-на-разных-стадиях:-в-сырье,-в-черновом-и-финальном-концентратах.-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Построение-модели" data-toc-modified-id="Построение-модели-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Построение модели</a></span><ul class="toc-item"><li><span><a href="#Функция-итоговой-sMAPE" data-toc-modified-id="Функция-итоговой-sMAPE-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Функция итоговой sMAPE</a></span></li><li><span><a href="#Обучение-разных-моделей-и-оценика-их-качества-кросс-валидацией." data-toc-modified-id="Обучение-разных-моделей-и-оценика-их-качества-кросс-валидацией.-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Обучение разных моделей и оценика их качества кросс-валидацией.</a></span><ul class="toc-item"><li><span><a href="#Воссоздадим-целевые-признаки-в-тестовой-выборке-взяв-данные-и-полной-выбоки" data-toc-modified-id="Воссоздадим-целевые-признаки-в-тестовой-выборке-взяв-данные-и-полной-выбоки-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Воссоздадим целевые признаки в тестовой выборке взяв данные и полной выбоки</a></span></li><li><span><a href="#Выделим-целевой-признак-и-признаки-для-этапа-rougher" data-toc-modified-id="Выделим-целевой-признак-и-признаки-для-этапа-rougher-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Выделим целевой признак и признаки для этапа rougher</a></span></li><li><span><a href="#Выделим-целевой-признак-и-признаки-для-этапа-final" data-toc-modified-id="Выделим-целевой-признак-и-признаки-для-этапа-final-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Выделим целевой признак и признаки для этапа final</a></span></li><li><span><a href="#Моделирование-для-этапа-rougher" data-toc-modified-id="Моделирование-для-этапа-rougher-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Моделирование для этапа rougher</a></span><ul class="toc-item"><li><span><a href="#Оценка-адекватности-модели" data-toc-modified-id="Оценка-адекватности-модели-3.2.4.1"><span class="toc-item-num">3.2.4.1&nbsp;&nbsp;</span>Оценка адекватности модели</a></span></li><li><span><a href="#Решающее-дерево" data-toc-modified-id="Решающее-дерево-3.2.4.2"><span class="toc-item-num">3.2.4.2&nbsp;&nbsp;</span>Решающее дерево</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.2.4.3"><span class="toc-item-num">3.2.4.3&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.2.4.4"><span class="toc-item-num">3.2.4.4&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Моделирование-для-этапа-final" data-toc-modified-id="Моделирование-для-этапа-final-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Моделирование для этапа final</a></span><ul class="toc-item"><li><span><a href="#Оценка-адекватности-модели" data-toc-modified-id="Оценка-адекватности-модели-3.2.5.1"><span class="toc-item-num">3.2.5.1&nbsp;&nbsp;</span>Оценка адекватности модели</a></span></li><li><span><a href="#Линейная-регрессия" data-toc-modified-id="Линейная-регрессия-3.2.5.2"><span class="toc-item-num">3.2.5.2&nbsp;&nbsp;</span>Линейная регрессия</a></span></li><li><span><a href="#Решающее-дерево" data-toc-modified-id="Решающее-дерево-3.2.5.3"><span class="toc-item-num">3.2.5.3&nbsp;&nbsp;</span>Решающее дерево</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.2.5.4"><span class="toc-item-num">3.2.5.4&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li></ul></li><li><span><a href="#Выбор-лучшей-модели-и-проверка-её-на-тестовой-выборке." data-toc-modified-id="Выбор-лучшей-модели-и-проверка-её-на-тестовой-выборке.-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Выбор лучшей модели и проверка её на тестовой выборке.</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Итог-итогов" data-toc-modified-id="Итог-итогов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Итог итогов</a></span></li></ul></div>

# %% [markdown]
# <h1>Проект: Восстановление золота из руды<span class="tocSkip"></span></h1>

# %% [markdown]
# Необходимо пдготовить прототип модели машинного обучения. Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Для этого нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.

# %% [markdown]
# **Технологический процесс!**
#
# Получение золота из руды.
# Когда добытая руда проходит первичную обработку, получается дроблёная смесь. Её отправляют на флотацию (обогащение) и двухэтапную очистку.

# %% [markdown]
# ![steps.jpg](attachment:steps.jpg)

# %% [markdown]
# **Опишем каждую стадию:**
#
# **1. Флотация**
#
# Во флотационную установку подаётся смесь золотосодержащей руды. После обогащения получается черновой концентрат и «отвальные хвосты», то есть остатки продукта с низкой концентрацией ценных металлов.
# На стабильность этого процесса влияет непостоянное и неоптимальное физико-химическое состояние флотационной пульпы (смеси твёрдых частиц и жидкости).
#
# **2. Очистка**
#
# Черновой концентрат проходит две очистки. На выходе получается финальный концентрат и новые отвальные хвосты.

# %% [markdown]
# **Описание данных**
#
# **1. Технологический процесс:**
# *   **Rougher feed** — исходное сырье
# *	**Rougher additions (или reagent additions)** — флотационные реагенты: Xanthate, Sulphate, Depressant
# *	**Xanthate** — ксантогенат (промотер, или активатор флотации);
# *	**Sulphate** — сульфат (на данном производстве сульфид натрия);
# *	**Depressant** — депрессант (силикат натрия).
# *	**Rougher process** (англ. «грубый процесс») — флотация
# *	**Rougher tails** — отвальные хвосты
# *	**Float banks** — флотационная установка
# *	**Cleaner process** — очистка
# *	**Rougher Au** — черновой концентрат золота
# *	**Final Au** — финальный концентрат золота
#
# **2. Параметры этапов**
# *	**air amount** — объём воздуха
# *	**fluid levels** — уровень жидкости
# *	**feed size** — размер гранул сырья
# *	**feed rate** — скорость подачи
#
# **3. Наименование признаков**
#
# **[этап].[тип_параметра].[название_параметра]**
#
# Пример: **rougher.input.feed_ag**
#
# **4 Возможные значения для блока [этап]:**
# *	**rougher** — флотация
# *	**primary_cleaner** — первичная очистка
# *	**secondary_cleaner** — вторичная очистка
# *	**final** — финальные характеристики
#
# **5. Возможные значения для блока [тип_параметра]:**
# *	**input** — параметры сырья
# *	**output** — параметры продукта
# *	**state** — параметры, характеризующие текущее состояние этапа
# *	**calculation** — расчётные характеристики

# %% [markdown]
# **Расчёт эффективности**
#
# Вам нужно смоделировать процесс восстановления золота из золотосодержащей руды.
#
# Эффективность обогащения рассчитывается по формуле
#
# \begin{align}
# Recovery= \frac{​​(C​​\times​​(F-T))​​}{​​(F​​\times​​(C-T))​​}​​\times​​100\%
# \end{align}
#
# где:
# -	C — доля золота в концентрате после флотации/очистки;
# -	F — доля золота в сырье/концентрате до флотации/очистки;
# -	T — доля золота в отвальных хвостах после флотации/очистки.
#
# Для прогноза коэффициента нужно найти долю золота в концентратах и хвостах. Причём важен не только финальный продукт, но и черновой концентрат.

# %% [markdown]
# **Метрика качества**
# Для решения задачи введём новую метрику качества — sMAPE (англ. Symmetric Mean Absolute Percentage Error, «симметричное среднее абсолютное процентное отклонение»).
# Она похожа на **MAE**, но выражается не в абсолютных величинах, а в относительных. Почему симметричная? Она одинаково учитывает масштаб и целевого признака, и предсказания.
# Метрика **sMAPE** вычисляется так:
#
# $$
# sMAPE = \frac{1}{N}\sum_{i=1}^N\frac{\mid y_{i}-\widehat{y}_{i}\mid}{(\left |y_{i}  \right |+\left |  \widehat{y_{i}}\right |)/2}\times 100\%
# $$
#
# Где
# - $y_{i}$ - значение целевого признака для объекта с порядковым номером i в выборке, на которой измеряется качество.
# - $\widehat{y}_{i}$ - значение предсказания для объекта с порядковым номером i, например, в тестовой выборке
# - $N$ - количество объектов в выборке
# - $\sum_{i=1}^{N}$ - суммирование по всем объектам выборки (i меняется от 1 до N)

# %% [markdown]
# Нужно спрогнозировать сразу две величины:
# 1.	эффективность обогащения чернового концентрата **rougher.output.recovery**;
# 2.	эффективность обогащения финального концентрата **final.output.recovery**.

# %% [markdown]
# **Итоговая метрика складывается из двух величин:**
#
# $$
# sMAPE_{itog} = 25\%\times sMAPE(rougher)+75\%\times sMAPE(final)
# $$

# %% [markdown]
# # Подготовка данных

# %% [markdown]
# ## Импортируем библиотеки

# %%
# установим последнюю версию scikit-learn
# !pip install scikit-learn==1.1.3

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from scipy import stats as st


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

from sklearn.dummy import DummyRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression 


from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import cross_val_score

from sklearn.metrics import (mean_absolute_error,
                             make_scorer)

# %%
# игнорирование предупреждений
import warnings
warnings.simplefilter("ignore")
warnings.filterwarnings("ignore")

# %%
# константа
RANDOM_STATE = 12345

# %% [markdown]
# **Считаем данные из csv-файлов в датафрейм и сохраним в переменные data.**
#
# Данные находятся в трёх файлах:
#
# - gold_recovery_train_new.csv — обучающая выборка;
# - gold_recovery_test_new.csv — тестовая выборка;
# - gold_recovery_full_new.csv — исходные данные.
#
# Путь к файлам:
# - /datasets/gold_recovery_train_new.csv.
# - /datasets/gold_recovery_test_new.csv.
# - /datasets/gold_recovery_full_new.csv.
#
#
# Данные индексируются датой и временем получения информации (признак date). Соседние по времени параметры часто похожи.

# %%
data_train = pd.read_csv('/datasets/gold_recovery_train_new.csv',
                         index_col='date', parse_dates=True)
data_test = pd.read_csv('/datasets/gold_recovery_test_new.csv',
                        index_col='date', parse_dates=True)
data_full = pd.read_csv('/datasets/gold_recovery_full_new.csv',
                        index_col='date', parse_dates=True)

# %% [markdown]
# выведим первые пять строк data_train

# %%
data_train.head()
# Out:
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# 2016-01-15 00:00:00                    42.192020              70.541216
# ...

# %% [markdown]
# **Функция по выводу основной информации по датафреймам**

# %%
def all_info(data):

    
    print('\033[1m'+'1.Вывод первых 5 строк датафрейма'+'\033[0m')
    print('')
    display(data.head())
    print('')
    
    print('\033[1m'+'2.Выведим основную информацию о датафрейме.'+'\033[0m')
    print('')
    display(data.info())
    print('')
    
    a = []
    b = []
    c = []
    count = 0
    for value in data.columns:
        a.append(data[value].isna().sum())
        b.append((data[value].isna().sum()/len(data))*100)
        c.append(value)
        count += 1
    ##display(pd.DataFrame(a.sort_values(ascending=False)))
    #on=["id", "месяц"]

    f = pd.DataFrame( {'name_columns': pd.Series(c),
                       'count': pd.Series(a),
                      'count,%': pd.Series(b)}
                    )
    print('')
    print('\033[1m'+'3.Таблица пропусков по столбцам.'+'\033[0m')
    print('')
    display(f.sort_values(by=['count'], ascending=False))
    print('')
    print('Колв-во столбцов с пропусками:', len(f[f['count']>0]))
    print('')
    
    print('\033[1m'+'4.Кол-во уникальных дупликатов.'+'\033[0m')
    print('')
    print('Уникальных дупликатов:', data.duplicated().sum())
    print('')
    
    
    print('\033[1m'+'5.Выведим общую информацию о данных в столбцах.'+'\033[0m')
    print('')
    display(data.describe())
    print('')

    
    print('\033[1m'+'6.Корреляция между столбцами'+'\033[0m')
    print('')
    sns.heatmap(data.corr()).set(title='Тепловая карта. Корреляционная матрица')
    sns.set(rc={"figure.figsize":(60,40)})

# %% [markdown]
# **Выведим общую информацию по обучающей выборке**

# %%
all_info(data_train)
# Out:
# 1.Вывод первых 5 строк датафрейма
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# ...

# %% [markdown]
# **Выведим общую информацию по тестовой выборке**

# %%
all_info(data_test)
# Out:
# 1.Вывод первых 5 строк датафрейма
#                      primary_cleaner.input.sulfate  \
# date
# 2016-09-01 00:59:59                     210.800909
# 2016-09-01 01:59:59                     215.392455
# 2016-09-01 02:59:59                     215.259946
# 2016-09-01 03:59:59                     215.336236
# 2016-09-01 04:59:59                     199.099327
#
#                      primary_cleaner.input.depressant  \
# date
# 2016-09-01 00:59:59                         14.993118
# 2016-09-01 01:59:59                         14.987471
# 2016-09-01 02:59:59                         12.884934
# 2016-09-01 03:59:59                         12.006805
# 2016-09-01 04:59:59                         10.682530
#
#                      primary_cleaner.input.feed_size  \
# date
# 2016-09-01 00:59:59                         8.080000
# 2016-09-01 01:59:59                         8.080000
# 2016-09-01 02:59:59                         7.786667
# 2016-09-01 03:59:59                         7.640000
# ...

# %% [markdown]
# **Выведим общую информацию по исходному датафрейму**

# %%
all_info(data_full)
# Out:
# 1.Вывод первых 5 строк датафрейма
#                      final.output.concentrate_ag  final.output.concentrate_pb  \
# date
# 2016-01-15 00:00:00                     6.055403                     9.889648
# 2016-01-15 01:00:00                     6.029369                     9.968944
# 2016-01-15 02:00:00                     6.055926                    10.213995
# 2016-01-15 03:00:00                     6.047977                     9.977019
# 2016-01-15 04:00:00                     6.148599                    10.142511
#
#                      final.output.concentrate_sol  \
# date
# 2016-01-15 00:00:00                      5.507324
# 2016-01-15 01:00:00                      5.257781
# 2016-01-15 02:00:00                      5.383759
# 2016-01-15 03:00:00                      4.858634
# 2016-01-15 04:00:00                      4.939416
#
#                      final.output.concentrate_au  final.output.recovery  \
# date
# ...

# %% [markdown]
# По выведеным данным можно сказать следующее:
#
# 1. data_train
# - Строк: 14149. Столбцов: 86
# - Кол-во столбцов с пропусками: 62.
# - Уникальные дупликаты отсутсвуют
# - более 11% от всего датаферйма пропущенных значений в одном из столбце.
#
# 2. data_test
# - Строк: 5290. Столбцов: 52
# - Кол-во столбцов с пропусками: 12.
# - Уникальные дупликаты отсутсвуют
#
# 3. data_full
# - Строк: 19439. Столбцов: 86
# - Кол-во столбцов с пропусками: 63.
# - Уникальные дупликаты отсутсвуют
# - более 8% от всего датаферйма пропущенных значений в одном из столбце.

# %%
len(data_train)+len(data_test)
# Out:
# 19439

# %% [markdown]
# Сумма кол-ва строк data_train и data_test совпадает с колв-вом в data_full.
#
# Однако кол-во столбцов в data_test и data_train не совпадает. В дальнейшем прежде чем выполнять машинное обучение необходиом будет привести их одиноковому количесву и убедится, что все необходимые пизнаки и целевые признаки присутсвуют Так как, к примеру, по условию в data_test отсутсвтуют целевые признаки.
#
# Все  значения в столбцах соответсвуют своему типу данных
#
# Построение общей гистограммы для всех числовых столбцов таблицы не проводилось, так как столбцов очень много и рано оценивать распределние данных и поиске выбросов и дисбаланса. Была попытка вывести матрицу корреляции между столбцами, но график получился не особо информативными

# %% [markdown]
# ## Эффективность обогащения

# %% [markdown]
# Необходимо проверить, что эффективность обогащения (флотации) рассчитана правильно на обучающей выборке для признака rougher.output.recovery

# %%
# доля золота в концентрате после флотации/очистки
C = data_train['rougher.output.concentrate_au']
#доля золота в сырье/концентрате до флотации/очистки
F = data_train['rougher.input.feed_au']
#доля золота в отвальных хвостах после флотации/очистки.
T = data_train['rougher.output.tail_au']

# %%
#создадим новый столбец recovery
data_train['recovery'] = ((C*(F-T))/(F*(C-T)))*100
data_train['recovery'].mean()
# Out:
# 82.70450164550293

# %%
#сравним с прзнаком rougher.output.recovery
data_train['rougher.output.recovery'].mean()
# Out:
# 82.70450164550293

# %% [markdown]
# Значения получились одинаковыми. Следовтельно эффективность похоже рассчитана правильно.

# %% [markdown]
# **Вычислим среднюю абсолютную ошибку (MAE) между нашими расчётами и значением признака.**

# %%
print(mean_absolute_error(data_train['recovery'], data_train['rougher.output.recovery']))
# Out:
# 9.73512347450521e-15

# %% [markdown]
# MAE получилос очень маленьким. Значит расчеты сделаны правильно и данные верны

# %% [markdown]
# Удалим столбец recovery, чтобы он не повлиял на дальнейше вычисления

# %%
data_train = data_train.drop('recovery', axis=1)

# %% [markdown]
# ## Анализ признаков в выборке

# %% [markdown]
# Проанализируйте признаки, недоступные в тестовой выборке. Что это за параметры? К какому типу относятся?

# %%
columns_not =[]
for value in data_train.columns:
    if value not in data_test.columns:
        columns_not.append(value)

# %%
print('Столбцы отсутсвующие в тестовой выборке')
print('')
display(columns_not)
print('')
print('Кол-во столбцов отсутсвующих в тестовой выборке', len(columns_not))
# Out:
# Столбцы отсутсвующие в тестовой выборке
# ['final.output.concentrate_ag',
#  'final.output.concentrate_pb',
#  'final.output.concentrate_sol',
#  'final.output.concentrate_au',
#  'final.output.recovery',
#  'final.output.tail_ag',
#  'final.output.tail_pb',
#  'final.output.tail_sol',
#  'final.output.tail_au',
#  'primary_cleaner.output.concentrate_ag',
#  'primary_cleaner.output.concentrate_pb',
#  'primary_cleaner.output.concentrate_sol',
#  'primary_cleaner.output.concentrate_au',
#  'primary_cleaner.output.tail_ag',
#  'primary_cleaner.output.tail_pb',
#  'primary_cleaner.output.tail_sol',
#  'primary_cleaner.output.tail_au',
#  'rougher.calculation.sulfate_to_au_concentrate',
#  'rougher.calculation.floatbank10_sulfate_to_au_feed',
#  'rougher.calculation.floatbank11_sulfate_to_au_feed',
#  'rougher.calculation.au_pb_ratio',
#  'rougher.output.concentrate_ag',
#  'rougher.output.concentrate_pb',
#  'rougher.output.concentrate_sol',
#  'rougher.output.concentrate_au',
# ...

# %% [markdown]
# Полученный столбцы можно удалить из data_train. Правда в этом перече присутствуют стобцы обозначающие целевые признаки: rougher.output.recovery и final.output.recovery. А они по условию отсутсвуют. Но при удалениие найденных столбцов, стоит учесть, что их нельзя удалять из data_train

# %%
columns_not.remove('final.output.recovery')

# %%
columns_not.remove('rougher.output.recovery')

# %%
print('Кол-во столбцов отсутсвующих в тестовой выборке', len(columns_not))
# Out:
# Кол-во столбцов отсутсвующих в тестовой выборке 32

# %%
data_train = data_train.drop(columns_not, axis=1)

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 14149 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 54 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   final.output.recovery                       14149 non-null  float64
#  1   primary_cleaner.input.sulfate               14129 non-null  float64
#  2   primary_cleaner.input.depressant            14117 non-null  float64
#  3   primary_cleaner.input.feed_size             14149 non-null  float64
#  4   primary_cleaner.input.xanthate              14049 non-null  float64
#  5   primary_cleaner.state.floatbank8_a_air      14145 non-null  float64
#  6   primary_cleaner.state.floatbank8_a_level    14148 non-null  float64
#  7   primary_cleaner.state.floatbank8_b_air      14145 non-null  float64
#  8   primary_cleaner.state.floatbank8_b_level    14148 non-null  float64
# ...

# %%
print('Кол-во столбцов с пропусками:',(data_train.isna().sum()>0).sum())
print('Всего столбцов:',len(data_train.columns))
# Out:
# Кол-во столбцов с пропусками: 44
# Всего столбцов: 54

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# Заполним пропуски в data_train и data_test. Так как данные выборки получены из data_full, то попробуем восстановить пропуски взяв данные из этой выборки.Для начал заполним пропуски в данной выборке. Заполнять будет методом интерполяции. предполагая, что у нас процессы идут последовательно. interpolate().

# %%
print('Кол-во столбцов с пропусками:',(data_full.isna().sum()>0).sum())
print('Всего столбцов:',len(data_full.columns))
# Out:
# Кол-во столбцов с пропусками: 63
# Всего столбцов: 86

# %%
data_full = data_full.interpolate()

# %%
data_full.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19439 entries, 2016-01-15 00:00:00 to 2018-08-18 10:59:59
# Data columns (total 86 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   final.output.concentrate_ag                         19439 non-null  float64
#  1   final.output.concentrate_pb                         19439 non-null  float64
#  2   final.output.concentrate_sol                        19439 non-null  float64
#  3   final.output.concentrate_au                         19439 non-null  float64
#  4   final.output.recovery                               19439 non-null  float64
#  5   final.output.tail_ag                                19439 non-null  float64
#  6   final.output.tail_pb                                19439 non-null  float64
#  7   final.output.tail_sol                               19439 non-null  float64
# ...

# %%
print('Кол-во столбцов с пропусками:',(data_full.isna().sum()>0).sum())
print('Всего столбцов:',len(data_full.columns))
# Out:
# Кол-во столбцов с пропусками: 0
# Всего столбцов: 86

# %% [markdown]
# Пропуски в исходном датасете заполнили. Теперь на основании полученных данных заолним пропуски в data_train и data_test

# %%
print('Кол-во столбцов с пропусками до заполнения:',(data_train.isna().sum()>0).sum())
print('Всего столбцов:',len(data_train.columns))
# Out:
# Кол-во столбцов с пропусками до заполнения: 44
# Всего столбцов: 54

# %%
data_train = data_train.fillna(data_full)

# %%
print('Кол-во столбцов с пропусками после заполнения:',(data_train.isna().sum()>0).sum())
print('Всего столбцов:',len(data_train.columns))
# Out:
# Кол-во столбцов с пропусками после заполнения: 0
# Всего столбцов: 54

# %%
print('Кол-во столбцов с пропусками до заполнения:',(data_test.isna().sum()>0).sum())
print('Всего столбцов:',len(data_test.columns))
# Out:
# Кол-во столбцов с пропусками до заполнения: 12
# Всего столбцов: 52

# %%
data_test = data_test.fillna(data_full)

# %%
print('Кол-во столбцов с пропусками до заполнения:',(data_test.isna().sum()>0).sum())
print('Всего столбцов:',len(data_test.columns))
# Out:
# Кол-во столбцов с пропусками до заполнения: 0
# Всего столбцов: 52

# %% [markdown]
# Все пропуски обработаны

# %% [markdown]
# ## Вывод

# %% [markdown]
# На данном этапе были загружены датафреймы:
#
# - gold_recovery_train_new.csv — обучающая выборка;
# - gold_recovery_test_new.csv — тестовая выборка;
# - gold_recovery_full_new.csv — исходные данные.
#
#
# По выведеным данным можно сказать следующее:
#
# 1. data_train
# - Строк: 14149. Столбцов: 86
# - Кол-во столбцов с пропусками: 62.
# - Уникальные дупликаты отсутсвуют
# - более 11% от всего датаферйма пропущенных значений в одном из столбце.
#
# 2. data_test
# - Строк: 5290. Столбцов: 52
# - Кол-во столбцов с пропусками: 12.
# - Уникальные дупликаты отсутсвуют
#
# 3. data_full
# - Строк: 19439. Столбцов: 86
# - Кол-во столбцов с пропусками: 63.
# - Уникальные дупликаты отсутсвуют
# - более 8% от всего датаферйма пропущенных значений в одном из столбце.
#
# Кол-во столбцов в data_test и data_train не совпадало. Былл проведен анализ признаков и скорректировано кол-во столбцов в данных.
#
# Все  значения в столбцах соответсвуют своему типу данных
#
# Построение общей гистограммы для всех числовых столбцов таблицы не проводилось, так как столбцов очень много и рано оценивать распределние данных и поиске выбросов и дисбаланса. Была попытка вывести матрицу корреляции между столбцами, но график получился не особо информативными
#
#
# Проверно, что эффективность обогащения (флотации) рассчитана правильно на обучающей выборке для признака rougher.output.recovery
# Также вычислена средняя абсолютная ошибка (MAE) между нашими расчётами и значением признака. MAE = 9.73512347450521e-15.
#
#
# Также были утсранены пропуски за счет применения метода интерполяции (с помощью метода interpolate) в основному датафрейму и последующего заполнения полученными данными оставшихся данных(методом fillna)
# Это было сделано так как было замечено, что данные упорядочены по времени. Значения параметров меняются постепенно. Процесс обогащения золота непрерывен. Следовательно значения пропущенное между двумя известными параметрами можно скорректировать интерполяцией.

# %% [markdown]
# # Анализ данных

# %% [markdown]
# ## Изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки

# %%
metal_concentration = pd.DataFrame(
    {
        'Этапы':['Исходная концетрация',
                        'Флотация',
                        'Первый этап очистки',
                        'Второй этап очистки'],
        'au':[data_full['rougher.input.feed_au'].mean(), 
              data_full['rougher.output.concentrate_au'].mean(),
              data_full['primary_cleaner.output.concentrate_au'].mean(),
              data_full['final.output.concentrate_au'].mean()
             ],
        'ag':[data_full['rougher.input.feed_ag'].mean(), 
              data_full['rougher.output.concentrate_ag'].mean(),
              data_full['primary_cleaner.output.concentrate_ag'].mean(),
              data_full['final.output.concentrate_ag'].mean()
             ],
        'pb':[data_full['rougher.input.feed_pb'].mean(), 
              data_full['rougher.output.concentrate_pb'].mean(),
              data_full['primary_cleaner.output.concentrate_pb'].mean(),
              data_full['final.output.concentrate_pb'].mean()
             ]
    }
)

# %%
print('Таблица концетрации металлов на разных этапах')
metal_concentration
# Out:
# Таблица концетрации металлов на разных этапах
#                   Этапы         au         ag        pb
# 0  Исходная концетрация   8.266097   8.794927  3.585473
# 1              Флотация  19.772000  11.994759  7.606272
# 2   Первый этап очистки  32.119400   8.442408  9.810373
# 3   Второй этап очистки  44.076513   5.168385  9.978819

# %% [markdown]
# Построим график изменеия концетрации на разных этапах

# %%
fig, ax = plt.subplots()

ax.plot(metal_concentration['Этапы'],
       metal_concentration['au'],
       label = 'au')
ax.plot(metal_concentration['Этапы'],
       metal_concentration['ag'],
       label = 'ag')
ax.plot(metal_concentration['Этапы'],
       metal_concentration['pb'],
       label = 'pb')

ax.legend()
fig.set_figwidth(15)    #  ширина Figure
fig.set_figheight(8)    #  высота Figure
ax.set_title('Изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки')
ax.set_xlabel('Этапы')
ax.set_ylabel('Концетрация')
plt.show()

# %% [markdown]
# **Вывод**
#
# Наблюдается, что концетрация золота с каждым последующим этапом равномерно растет.
# У серебра концетрация немного выросла на этапе флотации, но затем пошло на спад.
# У свинца концетрация росла до первой очистки и дальше перестало расти.

# %%
def gr(a):

    fig, ax = plt.subplots()

    sns.kdeplot(data=data_full, x="%s%s" % ('rougher.input.feed_', a), label='Исходная концетрация')
    sns.kdeplot(data=data_full, x="%s%s" % ('rougher.output.concentrate_', a), label='Флотация')
    sns.kdeplot(data=data_full, x="%s%s" % ('primary_cleaner.output.concentrate_', a), label='Первый этап очистки')
    sns.kdeplot(data=data_full, x="%s%s" % ('final.output.concentrate_', a), label='Второй этап очистки')

    fig.set_figwidth(15)    #  ширина Figure
    fig.set_figheight(8)    #  высота Figure
    ax.set_title("%s%s" % ('Изменение концентрации металла на различных этапах очистки: ', a))
    plt.legend()
    plt.show()

# %%
gr('au')

# %% [markdown]
# На графике отображено распределение изменения концетрации золота на различных этапах очистки.  Наблюдается росто концетрации с каждым последующим этапом очистки.

# %%
gr('pb')

# %% [markdown]
# На графике отображено распределение изменения концетрации свинца на различных этапах очистки.  Наблюдается рост концетрации вплоть по первого этапа очистки, затеп концетрация не менятеся, но  увеличивается кол-во значений данной концетрации в выборке.

# %%
gr('ag')

# %% [markdown]
# На графике отображено распределение изменения концетрации серебра на различных этапах очистки.  Наблюдается росто концетрации вплоть до флотации. Затем происходи поэтапное уменьшение концетрации металла.

# %% [markdown]
# Вывод:
# Как и ожидалось технологический процесс показыввает, что с каждым последующим этапом обработки руды концетрация золота растет.
# Концетрация остальных металлов уеньшается или останавливается на каком-то этапе на определенном значение.

# %% [markdown]
# ## Сравнение  распределения размеров гранул сырья на обучающей и тестовой выборках.

# %% [markdown]
# Построим график распределния данных в столбце **rougher.input.feed_size** в **data_test** и  **data_train**

# %%
fig, ax = plt.subplots()

ax.hist(data_train['rougher.input.feed_size'],bins = 300, alpha=0.5, label = 'Обучающая выборка')
ax.hist(data_test['rougher.input.feed_size'], bins = 300, alpha=0.3, label = 'Тестовая выборка')

fig.set_figwidth(15)    #  ширина Figure
fig.set_figheight(8)    #  высота Figure

ax.set_title('Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках')
ax.set_xlabel('Размер гранулы')
ax.set_ylabel('Кол-во')
ax.legend()
plt.show()

# %% [markdown]
# Посмотрим на распределние на диапазоне от (0, 150) по oX

# %%
fig, ax = plt.subplots()

ax.hist(data_train['rougher.input.feed_size'],bins = 300, alpha=0.5, label = 'Обучающая выборка')
ax.hist(data_test['rougher.input.feed_size'], bins = 300, alpha=0.3, label = 'Тестовая выборка')

fig.set_figwidth(15)    #  ширина Figure
fig.set_figheight(8)    #  высота Figure

ax.set_title('Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках')
ax.set_xlabel('Размер гранулы')
ax.set_ylabel('Кол-во')
ax.legend()
plt.xlim([0, 150])
plt.show()

# %% [markdown]
# Построи "ящик с усами" и посмотрим как дааные по отношеие к друг другу смещены

# %%
fig, ax = plt.subplots(1,2)

ax[0].boxplot(x=pd.DataFrame(data_train['rougher.input.feed_size']))
ax[1].boxplot(x=pd.DataFrame(data_test['rougher.input.feed_size']))

fig.set_figwidth(15)    #  ширина Figure
fig.set_figheight(8)    #  высота Figure

ax[0].set_title('Ящик с усами для обучающей выбокри')
ax[0].set_xlabel('rougher.input.feed_size')
ax[0].set_ylabel('Кол-во')
ax[0].set_ylim([0, 100])

ax[1].set_title('Ящик с усами для тестовой выборки')
ax[1].set_xlabel('rougher.input.feed_size')
ax[1].set_ylabel('Кол-во')

ax[1].set_ylim([0, 100])
plt.show()

# %%
data_train['rougher.input.feed_size'].describe()
# Out:
# count    14149.000000
# mean        60.097903
# std         23.023690
# min          9.659576
# 25%         48.950593
# 50%         55.269784
# 75%         65.982466
# max        484.967466
# Name: rougher.input.feed_size, dtype: float64

# %%
data_test['rougher.input.feed_size'].describe()
# Out:
# count    5290.000000
# mean       55.952835
# std        19.080372
# min         0.046369
# 25%        43.906504
# 50%        50.846843
# 75%        62.451165
# max       392.494040
# Name: rougher.input.feed_size, dtype: float64

# %% [markdown]
# По построенным графикам наблюдается, что графики между собой визуально отличаются. Их средние занчения между собой смещены.
# - У тестовой выборки среднее 55.
# - У обучающей выборки среднее 60.
#
# Также у обучающей выборки наблюдается большое количество выбросов до 25% порога.
#
# Оценим через гипотезы насколько сильно эти отличия.

# %% [markdown]
# **Проверим гипотезу о равенстве средних двух генеральных совокупностей**
#
# Проверка гипотезы: Среднее знаечние размеров гранул сырья на обучающей и тестовой выборках равные;
#
# ```
# H_0: Среднее значение размеров гранул сырья на обучающей = Среднее значение размеров гранул сырья на тестовой"`
# H_a: Среднее значение размеров гранул сырья на обучающей" ≠ Среднее значение размеров гранул сырья на тестовой"`
# alpha = 0.05
# ```

# %%
alpha = 0.05

results = st.ttest_ind(
    data_train['rougher.input.feed_size'], 
    data_test['rougher.input.feed_size'],
    equal_var = False )

print('p-значение: ', results.pvalue)


if results.pvalue < alpha:
    print("Отвергаем нулевую гипотезу")
else:
    print("Не получилось отвергнуть нулевую гипотезу")
# Out:
# p-значение:  8.76128160307778e-37
# Отвергаем нулевую гипотезу

# %% [markdown]
# Построим график распределния данных в столбце **rougher.input.feed_size** и **primary_cleaner.input.feed_size** в **data_test** и  **data_train** c помощью функции **sns.kdeplot**

# %%
fig, ax = plt.subplots()

sns.kdeplot(data=data_train, x="rougher.input.feed_size", label='train')
sns.kdeplot(data=data_test, x="rougher.input.feed_size", label='test')

fig.set_figwidth(15)    #  ширина Figure
fig.set_figheight(8)    #  высота Figure
ax.set_title('Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots()

sns.kdeplot(data=data_train, x="primary_cleaner.input.feed_size", label='train')
sns.kdeplot(data=data_test, x="primary_cleaner.input.feed_size", label='test')

fig.set_figwidth(15)    #  ширина Figure
fig.set_figheight(8)    #  высота Figure
ax.set_title('Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках')
plt.legend()
plt.show()

# %% [markdown]
# **Вывод**

# %% [markdown]
# Проведено сравнение распределения размеров гранул сырья на обучающей и тестовой выборках столбцов:
#
# 1) rougher.input.feed_size
#
# Построив график было замечено, что распределение у графиков отличается. У тренировочной выборки преобладают значения около 55, а у обучающей большое кол-во объектов сконцетрировано до 55.
#
# 2) primary_cleaner.input.feed_size.
#
# Можем видеть, что распределения отличаются незначительно. Немного отличается частота встречи данных значений выборке.
#
#
# Из-за первого распределения не желательно дальше работать с такими данными.

# %% [markdown]
# ## Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах.

# %% [markdown]
# **Расчет суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах**

# %%
data_sum = []
data_sum = pd.DataFrame(
    {
        'imput':
    data_full['rougher.input.feed_ag'] + 
    data_full['rougher.input.feed_pb'] + 
    data_full['rougher.input.feed_au'] + 
    data_full['rougher.input.feed_sol'],
        'output':
    data_full['rougher.output.concentrate_ag'] + 
    data_full['rougher.output.concentrate_pb'] + 
    data_full['rougher.output.concentrate_au'] + 
    data_full['rougher.output.concentrate_sol'],
        'final':
    data_full['final.output.concentrate_ag'] + 
    data_full['final.output.concentrate_pb'] + 
    data_full['final.output.concentrate_au'] + 
    data_full['final.output.concentrate_sol'] 
}
)

# %%
data_sum.head()
# Out:
#                          imput     output      final
# date
# 2016-01-15 00:00:00  51.680034  66.424950  63.644396
# 2016-01-15 01:00:00  50.659114  67.012710  63.957723
# 2016-01-15 02:00:00  50.609929  66.103793  64.311180
# 2016-01-15 03:00:00  51.061546  65.752751  63.573449
# 2016-01-15 04:00:00  47.859163  65.908382  64.004667

# %% [markdown]
# **Построим гистограммы**

# %%
fig, ax = plt.subplots(3,1)

ax[0].hist(x=pd.DataFrame(data_sum['imput']), bins = 200)
ax[1].hist(x=pd.DataFrame(data_sum['output']), bins = 200)
ax[2].hist(x=pd.DataFrame(data_sum['final']), bins = 200)

fig.set_figwidth(15)    #  ширина Figure
fig.set_figheight(25)    #  высота Figure

ax[0].set_title('Гистограмма суммарной концентрации всех веществ на стадии в сырье')
ax[0].set_xlabel('Концетрация')
ax[0].set_ylabel('Кол-во')

ax[1].set_title('Гистограмма суммарной концентрации всех веществ на стадии в черновом концтрате')
ax[1].set_xlabel('Концетрация')
ax[1].set_ylabel('Кол-во')

ax[2].set_title('Гистограмма суммарной концентрации всех веществ на стадии в финальном концетрате')
ax[2].set_xlabel('Концетрация')
ax[2].set_ylabel('Кол-во')

plt.show()

# %% [markdown]
# На графике гистограммы суммарной концентрации всех веществ на стадии в черновом концтрате наблюдается всплеск значений около нуля. При том, что на этапе сырь и последующей финальной концетрации всплески наблдаются, но уже значительно меньше.
# Также наблюдается увеличения суммарной концетрации веществ с каждым последующим этапом. На последнем этапе кол-ва знаечний с концетрацией в пределах 60-80

# %% [markdown]
# Стоит в дальнейшем уточнить откуда могли взяться такие значения. Вдруг на одном из этапов произошла ошибка в фиксировании концетрации у разных материалов, тогда это могло повлиять и на другие замеры. Но при расмотрении распределния концетраци у разных металлов явных выбросов не наблюдалось.
# Удалим дстроки в которых суммарное значение концетрациив сех веществ на разынх стадиях равно нулю.

# %% [markdown]
# **Напишем функцию удалению строк в которых суммарное значение концентрации всех веществ на разынх стадиях равно нулю в data_ful, data_train, data_test**
#
# - Стадия в сырье rougher.input.feed
# - Стадия в черновом концентрате  rougher.output.concentrate
# - Стадия в финальном концентрате final.output.concentrate

# %%
def udalenie_full(a, data_full, data_train, data_test):
    
    #Сохраним индексы(в нашем случае дату и время) в которых суммарное 
    #значение концентрации всех веществ на разынх стадиях равно нулю.
    
    data_dull_nul_index = data_full.loc[
    (data_full["%s%s" % (a, '_ag')] \
    + data_full["%s%s" % (a, '_pb')] \
    + data_full["%s%s" % (a, '_au')] \
    + data_full["%s%s" % (a, '_sol')]) == 0].index
    
    
    #удалим строки с найденным индексом
    data_full = data_full.drop(index = data_dull_nul_index, 
                               axis = 0)
    
    #найдем индексы, которые находятся в data_train из списка data_full_nul_index
    data_train_nul_index = list(
        set(data_dull_nul_index) \
        & set(data_train.index)
    )
    
    #удалим строки с найденным индексом
    data_train = data_train.drop(data_train_nul_index, axis = 0)
    
    #найдем индексы, которые находятся в data_test из списка data_full_nul_index
    
    data_test_sum_nul_index = list(
        set(data_dull_nul_index) \
        & set(data_test.index)
    )
    
    #удалим строки с найденным индексом
    data_test = data_test.drop(index = data_test_sum_nul_index, 
                               axis = 0)
    
    return  data_full, data_train, data_test

# %%
data_full, data_train, data_test = udalenie_full('rougher.input.feed', data_full, data_train, data_test)

# %%
data_full, data_train, data_test = udalenie_full('rougher.output.concentrate', data_full, data_train, data_test)

# %%
data_full, data_train, data_test = udalenie_full('final.output.concentrate', data_full, data_train, data_test)

# %% [markdown]
# ## Вывод

# %% [markdown]
# 1. Изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки
# Наблюдается, что концетрация золота с каждым последующим этапом равномерно растет.
# У серебра концетрация немного выросла на этапе флотации, но затем пошло на спад.
# У свинца концетрация росла до первой очистки и дальше перестало расти.
#
#
# 2. Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках
#
# Проведено сравнение распределения размеров гранул сырья на обучающей и тестовой выборках столбцов:
#
# 1) rougher.input.feed_size
#
# Построив график было замечено, что распределение у графиков отличается. У тренировочной выборки преобладают значения около 55, а у обучающей большое кол-во объектов сконцетрировано до 55.
#
# 2) primary_cleaner.input.feed_size.
#
# Можем видеть, что распределения отличаются незначительно. Немного отличается частота встречи данных значений выборке.
#
#
# Из-за первого распределения не желательно дальше работать с такими данными.
#
# 3. Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах
#
# На графике гистограммы суммарной концентрации всех веществ на стадии в черновом концтрате наблюдается всплеск значений около нуля. При том, что на этапе сырье и последующей финальной концетрации всплески наблдаются, но уже значительно меньше.
# Также наблюдается увеличения суммарной концетрации веществ с каждым последующим этапом. На последнем этапе кол-ва знаечний с концетрацией в пределах 60-80
# В рамках данной работы были выполно удаление строк на каждом этапе в которых суммарное значение равно нулю.

# %% [markdown]
# # Построение модели

# %% [markdown]
# ## Функция итоговой sMAPE

# %% [markdown]
# **Функция sMAPE**

# %%
def sMAPE(target,predict):
    score = (
        (1/len(target))\
        *np.sum(abs(target - predict)\
                /((abs(target)+abs(predict))/2))*100
    )
    return score

# %%
scorer = make_scorer(sMAPE, greater_is_better=False)

# %% [markdown]
# **Функция итоговой sMAPE**

# %%
def sMAPE_itog(sMAPE_rougher,sMAPE_final):
    return (0.25*sMAPE_rougher + 0.75*sMAPE_final)

# %% [markdown]
# ## Обучение разных моделей и оценика их качества кросс-валидацией.

# %% [markdown]
# ### Воссоздадим целевые признаки в тестовой выборке взяв данные и полной выбоки

# %%
target_test = (data_full['rougher.output.recovery']).reset_index()

# %%
target_test.head()
# Out:
#                  date  rougher.output.recovery
# 0 2016-01-15 00:00:00                87.107763
# 1 2016-01-15 01:00:00                86.843261
# 2 2016-01-15 02:00:00                86.842308
# 3 2016-01-15 03:00:00                87.226430
# 4 2016-01-15 04:00:00                86.688794

# %% [markdown]
# Появился столбец date вне индексации. По нему и будем объединять таблицы data_test и target_test

# %%
data_test = data_test.reset_index()

# %%
data_test = data_test.merge(target_test, how = 'left', on = 'date')

# %%
target_test_1 = (data_full['final.output.recovery']).reset_index()

# %%
data_test = data_test.merge(target_test_1, how = 'left', on = 'date')

# %%
data_test = data_test.drop('date', axis=1)

# %% [markdown]
# Удалим столбец date

# %%
data_test.head()
# Out:
#    primary_cleaner.input.sulfate  primary_cleaner.input.depressant  \
# 0                     210.800909                         14.993118
# 1                     215.392455                         14.987471
# 2                     215.259946                         12.884934
# 3                     215.336236                         12.006805
# 4                     199.099327                         10.682530
#
#    primary_cleaner.input.feed_size  primary_cleaner.input.xanthate  \
# 0                         8.080000                        1.005021
# 1                         8.080000                        0.990469
# 2                         7.786667                        0.996043
# 3                         7.640000                        0.863514
# 4                         7.530000                        0.805575
#
#    primary_cleaner.state.floatbank8_a_air  \
# 0                             1398.981301
# 1                             1398.777912
# ...

# %%
#data_test.shape

# %% [markdown]
# ### Выделим целевой признак и признаки для этапа rougher

# %% [markdown]
# Прежде чем проводить разбиение, скорректируем индексацию. В data_train у нас индексация идет по времени. Создадим новую и избавимся от столбца времени, чтобы у нас потом не было проблем в процессе обучения моделей.

# %%
data_train = data_train.reset_index()

# %%
#data_train.head()

# %%
data_train = data_train.drop('date', axis=1)

# %%
#data_train.head()

# %%
#data_train.shape

# %% [markdown]
# ***Выделим столбцы относящиеся к этапу флотации**

# %%
train_rougher = data_train.filter(regex='^rougher',axis=1)

# %%
test_rougher = data_test.filter(regex='^rougher',axis=1)

# %% [markdown]
# **Выделяем целевые признаки в обучающей и тестововй выорке**

# %%
#целевые признаки (rougher)
target_train_rougher = train_rougher['rougher.output.recovery']
target_test_rougher = test_rougher['rougher.output.recovery']

# %%
##признаки (rougher)
features_train_rougher = train_rougher.drop(
    ['rougher.output.recovery'], 
    axis=1
)

features_test_rougher = test_rougher.drop(
    ['rougher.output.recovery'], 
    axis=1
)

# %% [markdown]
# **Масштабирование данных**

# %%
numeric = features_train_rougher.columns

# %%
scaler = StandardScaler()
scaler.fit(features_train_rougher[numeric]) 

features_train_rougher[numeric] = scaler.transform(
    features_train_rougher[numeric]
)
features_test_rougher[numeric] = scaler.transform(
    features_test_rougher[numeric]
)

# %% [markdown]
# ### Выделим целевой признак и признаки для этапа final

# %% [markdown]
# **Выделяем целевые признаки в обучающей и тестововй выорке**

# %%
target_train_final = data_train['final.output.recovery']
target_test_final = data_test['final.output.recovery']

# %%
features_train_final = data_train.drop(
    ['rougher.output.recovery','final.output.recovery'], 
    axis=1
)

features_test_final = data_test.drop(
    ['rougher.output.recovery','final.output.recovery'], 
    axis=1
)

# %% [markdown]
#  **Масштабирование данных**

# %%
numeric = features_train_final.columns

# %%
scaler = StandardScaler()
scaler.fit(features_train_final[numeric]) 

features_train_final[numeric] = scaler.transform(
    features_train_final[numeric]
)
features_test_final[numeric] = scaler.transform(
    features_test_final[numeric]
)

# %% [markdown]
# ### Моделирование для этапа rougher

# %% [markdown]
# #### Оценка адекватности модели

# %% [markdown]
# Оценим адекватность модели относительно среднего значения

# %%
dummy = DummyRegressor(strategy = 'mean')
dummy.fit(features_train_rougher, target_train_rougher)
predict = dummy.predict(features_test_rougher)
rougher_score_dummy = abs(sMAPE(target_test_rougher,predict))
print('Средняя оценка качества константной модели:', rougher_score_dummy)
# Out:
# Средняя оценка качества константной модели: 5.378767876637099

# %% [markdown]
# #### Решающее дерево

# %%
# %%time
best_model_tree_rougher = None 
best_depth_tree_rougher = 0
best_final_tree_score_rougher = 100_000

for depth in range(1, 11, 1):
    model = DecisionTreeRegressor(
        max_depth=depth, 
        random_state=RANDOM_STATE
    ) 
    
    scores = cross_val_score(model, 
                         features_train_rougher, 
                         target_train_rougher, 
                         cv=3,
                         n_jobs=-1,
                         scoring=scorer)
    

    final_score = scores.mean()
    if abs(final_score) < best_final_tree_score_rougher:
        best_model_tree_rougher = model
        best_final_tree_score_rougher = abs(final_score)
        best_depth_tree_rougher = depth
        
print('Процесс завершен')  
print('Максимальная глубина деревьев:', best_depth_tree_rougher)
print('Средняя оценка качества модели методом кросс-валидации:', best_final_tree_score_rougher)
# Out:
# Процесс завершен
# Максимальная глубина деревьев: 2
# Средняя оценка качества модели методом кросс-валидации: 8.025839006031724
# CPU times: user 3.23 s, sys: 5.6 ms, total: 3.24 s
# Wall time: 3.25 s

# %% [markdown]
# #### Линейная регрессия

# %%
# %%time
model_linear_rougher = LinearRegression()
model_linear_rougher.fit(features_train_rougher, target_train_rougher)
scores = cross_val_score(model_linear_rougher, 
                         features_train_rougher, 
                         target_train_rougher, 
                         cv=3, 
                         n_jobs=-1,
                         scoring=scorer
                        )

rougher_linear_score = abs(scores.mean())
print('Средняя оценка качества модели методом кросс-валидации:', rougher_linear_score)
# Out:
# Средняя оценка качества модели методом кросс-валидации: 8.688414720183333
# CPU times: user 309 ms, sys: 369 ms, total: 678 ms
# Wall time: 680 ms

# %% [markdown]
# #### Случайный лес

# %%
# %%time
best_model_forest_rougher = None 

best_depth_forest_rougher = 0
best_n_estimators_rougher = 0
best_final_forest_score_rougher = 100_000

for est in range(10, 30, 5):
    for depth in range(1, 11, 1):
        model = RandomForestRegressor(
            random_state=RANDOM_STATE, 
            n_estimators=est, 
            max_depth = depth) 
        
        scores = cross_val_score(
            model,
            features_train_rougher,
            target_train_rougher,
            cv=3,
            n_jobs=-1,
            scoring=scorer
        )
    
        final_score = scores.mean()
        
        if abs(final_score) < best_final_forest_score_rougher:
            best_model_forest_rougher = model
            best_final_forest_score_rougher = abs(final_score)
            best_depth_forest_rougher = depth
            best_n_estimators_rougher = est
        
print('Процесс завершен')  
print('Средняя оценка качества модели методом кросс-валидации:', best_final_forest_score_rougher)
print('')
print('Гиперпараметры:')
print("Лучшая max_depth:", best_depth_forest_rougher)
print("Лучшая n_estimators:", best_n_estimators_rougher)
# Out:
# Процесс завершен
# Средняя оценка качества модели методом кросс-валидации: 7.7499073296637375
#
# Гиперпараметры:
# Лучшая max_depth: 3
# Лучшая n_estimators: 25
# CPU times: user 2min 7s, sys: 399 ms, total: 2min 7s
# Wall time: 2min 8s

# %% [markdown]
# ### Моделирование для этапа final

# %% [markdown]
# #### Оценка адекватности модели

# %% [markdown]
# Оценим адекватность модели относительно среднего значения

# %%
dummy = DummyRegressor(strategy = 'mean')
dummy.fit(features_train_final, target_train_final)
predict = dummy.predict(features_test_final)
final_score_dummy = abs(sMAPE(target_test_final,predict))
print('Средняя оценка качества константной модели:', final_score_dummy)
# Out:
# Средняя оценка качества константной модели: 8.562549464305668

# %% [markdown]
# #### Линейная регрессия

# %%
# %%time
model_linear_final = LinearRegression()
model_linear_final.fit(features_train_final, target_train_final)
scores = cross_val_score(model_linear_final, 
                         features_train_final, 
                         target_train_final, 
                         cv=3, 
                         n_jobs=-1,
                         scoring=scorer
                        )

final_linear_score = abs(scores.mean())
print('Средняя оценка качества модели методом кросс-валидации:', final_linear_score)
# Out:
# Средняя оценка качества модели методом кросс-валидации: 13.530996031955395
# CPU times: user 432 ms, sys: 318 ms, total: 751 ms
# Wall time: 703 ms

# %% [markdown]
# #### Решающее дерево

# %%
# %%time
best_model_tree_final = None 
best_depth_tree_final = 0
best_final_tree_score_final = 100_000

for depth in range(1, 11, 1):
    model = DecisionTreeRegressor(
        max_depth=depth, 
        random_state=RANDOM_STATE
    ) 
    
    scores = cross_val_score(model, 
                         features_train_final, 
                         target_train_final, 
                         cv=5, 
                         scoring=scorer
                            )
    

    final_score = scores.mean()
    if abs(final_score) < best_final_tree_score_final:
        best_model_tree_final = model
        best_final_tree_score_final = abs(final_score)
        best_depth_tree_final = depth
        
print('Процесс завершен')  
print('Максимальная глубина деревьев:', best_depth_tree_final)
print('Средняя оценка качества модели методом кросс-валидации:', best_final_tree_score_final)
# Out:
# Процесс завершен
# Максимальная глубина деревьев: 2
# Средняя оценка качества модели методом кросс-валидации: 9.387534526765947
# CPU times: user 14.3 s, sys: 38.6 ms, total: 14.3 s
# Wall time: 14.4 s

# %% [markdown]
# #### Случайный лес

# %%
# %%time
best_model_forest_final = None 

best_depth_forest_final = 0
best_n_estimators_final = 0
best_final_forest_score_final = 100_000

for est in range(10, 30, 5):
    for depth in range(1, 11, 1):
        model = RandomForestRegressor(
            random_state=RANDOM_STATE, 
            n_estimators=est, 
            max_depth = depth) 
        
        scores = cross_val_score(
            model,
            features_train_final,
            target_train_final,
            cv=3,
            n_jobs=-1,
            scoring=scorer
        )
    
        final_score = scores.mean()
        
        if abs(final_score) < best_final_forest_score_final:
            best_model_forest_final = model
            best_final_forest_score_final = abs(final_score)
            best_depth_forest_final = depth
            best_n_estimators_final = est
        
print('Процесс завершен')  
print('Средняя оценка качества модели методом кросс-валидации:', best_final_forest_score_final)
print('')
print('Гиперпараметры:')
print("Лучшая max_depth:", best_depth_forest_final)
print("Лучшая n_estimators:", best_n_estimators_final)
# Out:
# Процесс завершен
# Средняя оценка качества модели методом кросс-валидации: 10.269740277275027
#
# Гиперпараметры:
# Лучшая max_depth: 2
# Лучшая n_estimators: 25
# CPU times: user 4min 54s, sys: 664 ms, total: 4min 55s
# Wall time: 4min 55s

# %% [markdown]
# **Вычслим Итоговое sMAPE" для каждой модели**

# %%
print('Итоговое sMAPE на обучающей выборке для Линейной регрессии ', 
      sMAPE_itog(
          rougher_linear_score, 
          final_linear_score
      )
     )
# Out:
# Итоговое sMAPE на обучающей выборке для Линейной регрессии  12.320350704012379

# %%
print('Итоговое sMAPE на обучающей выборке для модели Решающее дерево', 
      sMAPE_itog(
          best_final_tree_score_rougher, 
          best_final_tree_score_final
      )
     )
# Out:
# Итоговое sMAPE на обучающей выборке для модели Решающее дерево 9.047110646582391

# %%
print('Итоговое sMAPE на обучающей выборке для модели Случайный лес', 
      sMAPE_itog(
          best_final_forest_score_rougher, 
          best_final_forest_score_final
      )
     )
# Out:
# Итоговое sMAPE на обучающей выборке для модели Случайный лес 9.639782040372204

# %% [markdown]
# ## Выбор лучшей модели и проверка её на тестовой выборке.

# %% [markdown]
#  Итогового sMAPE на обучающей выборке показало лучший результат на модели Случаный лес
#
#  с гиперпараметрами на этапе флотации(rougher):
#
# - Лучшая max_depth: 3
# - Лучшая n_estimators: 25
#
#  с гиперпараметрами на этапе final :
#
# - Лучшая max_depth: 3
# - Лучшая n_estimators: 15
#
# Проверим данную модель с данными параметрами на тестовой выборке

# %% [markdown]
# Этап флотации(rougher). Расчет на тестовой выборке

# %%
model_forest_final_test = RandomForestRegressor(
    random_state=RANDOM_STATE, 
    n_estimators=25, 
    max_depth = 3)
model_forest_final_test.fit(features_train_rougher,target_train_rougher) 
predict_rougher = model_forest_final_test.predict(features_test_rougher)

# %%
sMAPE_rougher = sMAPE(target_test_rougher,predict_rougher)
print('sMAPE_rougher на тестовой выборке', sMAPE_rougher)
# Out:
# sMAPE_rougher на тестовой выборке 4.896602772886467

# %% [markdown]
# Этап final. Расчет на тестовой выборке

# %%
model_forest_final_test = RandomForestRegressor(
    random_state=RANDOM_STATE, 
    n_estimators=15, 
    max_depth = 3)
model_forest_final_test.fit(features_train_final,target_train_final) 
predict_final = model_forest_final_test.predict(features_test_final)

# %%
sMAPE_final = sMAPE(target_test_final,predict_final)
print('sMAPE_final на тестовой выборке', sMAPE_final)
# Out:
# sMAPE_final на тестовой выборке 7.923626262216615

# %%
print('Итоговое sMAPE на тестовой выборке', sMAPE_itog(sMAPE_rougher, sMAPE_final))
# Out:
# Итоговое sMAPE на тестовой выборке 7.166870389884078

# %%
print('Итоговое sMAPE на тестовой выборке для константной модели', sMAPE_itog(rougher_score_dummy, final_score_dummy))
# Out:
# Итоговое sMAPE на тестовой выборке для константной модели 7.766604067388526

# %% [markdown]
# ## Вывод

# %% [markdown]
# Была написана функция для вычисления итоговой sMAPE.
#
# Воссозданы в тестовой выборке целевые признаки.
#
# Выделены целевые признаки и признаки у тетсовой и тренировочной выборки.
#
# Проведено моедлировани для этапов rougher и final.
#
# Были рассмотрены модели: Решающее дерево, Случайный лес, Линейная ререссия.
#
# Расчитаны метрики на обучающей выборке:
# - Итоговое sMAPE на обучающей выборке для Линейной регрессии  9.908491628373296
# - Итоговое sMAPE на обучающей выборке для модели Решающее дерево 8.897320011132253
# - Итоговое sMAPE на обучающей выборке для модели Случайный лес 8.584771869068927
#
# Лучшей оказалась модель: Случайный лес
#
# На этапе флотации(rougher) Случаный лес с гиперпараметрами:
#
# - Лучшая max_depth: 3
# - Лучшая n_estimators: 25
#
# На этапе final  Случаный лес с гиперпараметрами:
#
# - Лучшая max_depth: 3
# - Лучшая n_estimators: 15
#
#
# Расчитаны метрики на тестовой выборке:
# - sMAPE_rougher на тестовой выборке 4.896602772886467
# - sMAPE_final на тестовой выборке 7.923626262216615
# - Итоговое sMAPE на тестовой выборке 7.166870389884078
# - Итоговое sMAPE на тестовой выборке для константной модели 7.766604067388526
#
# Значение на тестовой выборке получилось меньше среднего константной модели. Следовательно модель обучается корректно

# %% [markdown]
# # Итог итогов

# %% [markdown]
# Подготовлен прототип модели машинного обучения. Предложено решение для эффективной работы промышленных предприятий.
#
# Модель предсказывает коэффициент восстановления золота из золотосодержащей руды.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Этапы выполнения проекта:
#
# **1. Шаг 1 Подготовка данных**
#
# На данном этапе были загружены датафреймы:
#
# - gold_recovery_train_new.csv — обучающая выборка;
# - gold_recovery_test_new.csv — тестовая выборка;
# - gold_recovery_full_new.csv — исходные данные.
#
#
# По выведеным данным можно сказать следующее:
#
# 1. data_train
# - Строк: 14149. Столбцов: 86
# - Кол-во столбцов с пропусками: 62.
# - Уникальные дупликаты отсутсвуют
# - более 11% от всего датаферйма пропущенных значений в одном из столбце.
#
# 2. data_test
# - Строк: 5290. Столбцов: 52
# - Кол-во столбцов с пропусками: 12.
# - Уникальные дупликаты отсутсвуют
#
# 3. data_full
# - Строк: 19439. Столбцов: 86
# - Кол-во столбцов с пропусками: 63.
# - Уникальные дупликаты отсутсвуют
# - более 8% от всего датаферйма пропущенных значений в одном из столбце.
#
# Кол-во столбцов в data_test и data_train не совпадало. Былл проведен анализ признаков и скорректировано кол-во столбцов в данных.
#
# Все  значения в столбцах соответсвуют своему типу данных
#
# Построение общей гистограммы для всех числовых столбцов таблицы не проводилось, так как столбцов очень много и рано оценивать распределние данных и поиске выбросов и дисбаланса. Была попытка вывести матрицу корреляции между столбцами, но график получился не особо информативными
#
#
# Проверно, что эффективность обогащения (флотации) рассчитана правильно на обучающей выборке для признака rougher.output.recovery
# Также вычислена средняя абсолютная ошибка (MAE) между нашими расчётами и значением признака. MAE = 9.73512347450521e-15.
#
#
# Также были утсранены пропуски за счет применения метода интерполяции (с помощью метода interpolate) в основному датафрейму и последующего заполнения полученными данными оставшихся данных(методом fillna)
#
#
# **2. Шаг2 Анализ данных**
#
# - Изменение концентрации металлов (Au, Ag, Pb) на различных этапах очистки
#
# Наблюдается, что концетрация золота с каждым последующим этапом равномерно растет.
#
# У серебра концетрация немного выросла на этапе флотации, но затем пошло на спад.
#
# У свинца концетрация росла до первой очистки и дальше перестало расти.
#
#
# - Сравнение распределения размеров гранул сырья на обучающей и тестовой выборках
#
# Проведено сравнение распределения размеров гранул сырья на обучающей и тестовой выборках столбцов:
#
# 1) rougher.input.feed_size
#
# Построив график было замечено, что распределение у графиков отличается. У тренировочной выборки преобладают значения около 55, а у обучающей большое кол-во объектов сконцетрировано до 55.
#
# 2) primary_cleaner.input.feed_size.
#
# Можем видеть, что распределения отличаются незначительно. Немного отличается частота встречи данных значений выборке.
#
#
# Из-за первого распределения не желательно дальше работать с такими данными.
#
# - Исследование суммарной концентрации всех веществ на разных стадиях: в сырье, в черновом и финальном концентратах
#
# На графике гистограммы суммарной концентрации всех веществ на стадии в черновом концтрате наблюдается всплеск значений около нуля. При том, что на этапе сырь и последующей финальной концетрации такого всплеска не наблюдается.
# Нули составляют 2% от всех значений.
# В рамках данной работы предлагается оставить.
#
#
# **3. Шаг3 Построеие модели**
#
# Была написана функция для вычисления итоговой sMAPE.
#
# Воссозданы в тестовой выборке целевые признаки.
#
# Выделены целевые признаки и признаки у тетсовой и тренировочной выборки.
#
# Проведено моедлировани для этапов rougher и final.
#
# Были рассмотрены модели: Решающее дерево, Случайный лес, Линейная ререссия.
#
# Расчитаны метрики на обучающей выборке:
# - Итоговое sMAPE на обучающей выборке для Линейной регрессии  9.908491628373296
# - Итоговое sMAPE на обучающей выборке для модели Решающее дерево 8.897320011132253
# - Итоговое sMAPE на обучающей выборке для модели Случайный лес 8.584771869068927
#
# Лучшей оказалась модель: Случайный лес
#
# На этапе флотации(rougher) Случаный лес с гиперпараметрами:
#
# - Лучшая max_depth: 3
# - Лучшая n_estimators: 25
#
# На этапе final  Случаный лес с гиперпараметрами:
#
# - Лучшая max_depth: 3
# - Лучшая n_estimators: 15
#
#
# Расчитаны метрики на тестовой выборке:
# - sMAPE_rougher на тестовой выборке 4.896602772886467
# - sMAPE_final на тестовой выборке 7.923626262216615
# - Итоговое sMAPE на тестовой выборке 7.166870389884078
# - Итоговое sMAPE на тестовой выборке для константной модели 7.766604067388526
#
# Значение на тестовой выборке получилось меньше среднего константной модели. Следовательно модель обучается корректно
